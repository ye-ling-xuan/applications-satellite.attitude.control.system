# %% [markdown]
# 本周我们将把所有知识整合起来，构建一个完整的单轴卫星姿态PID控制仿真系统，并实现可视化。

# %% [markdown]
# Day 1-2：系统设计
# 系统模块
# 卫星模型：包含动力学和状态
#
# PID控制器：计算控制力矩
#
# 仿真引擎：主循环，更新状态
#
# 数据记录：保存历史数据
#
# 可视化：绘制结果
#
# 代码结构
# simulation/
# ├── satellite.py      # 卫星类
# ├── controller.py     # PID控制器类
# ├── simulator.py      # 仿真主程序
# └── plotter.py        # 绘图工具
