# %%
! pip install gymnasium

# %%
! pip install "gymnasium[classic-control]"
# Out:
# ...
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/14.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/14.8 MB 1.1 MB/s eta 0:00:13
#      -- ------------------------------------- 1.0/14.8 MB 1.7 MB/s eta 0:00:09
#      ----- ---------------------------------- 2.1/14.8 MB 2.6 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.9/14.8 MB 4.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 6.0/14.8 MB 5.3 MB/s eta 0:00:02
#      ----------------------- ---------------- 8.7/14.8 MB 6.4 MB/s eta 0:00:01
#      ------------------------------ --------- 11.3/14.8 MB 7.3 MB/s eta 0:00:01
# ...

# %%
! pip install gymnasium
